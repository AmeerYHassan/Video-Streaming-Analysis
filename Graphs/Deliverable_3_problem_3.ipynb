# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('final_dataset.csv')
df
# Out:
#     Unnamed: 0                                             title  \
# 0            4                                         Limitless
# 1            5                 Gilmore Girls: A Year in the Life
# 2            8                                           Charmed
# 3           10                                           Revenge
# 4           11                                   The Jungle Book
# 5           13  American Crime Story: The People v. O.J. Simpson
# 6           14                                    Dave Chappelle
# 7           17                                       Cheer Squad
# 8           21                     Barbie Life in the Dreamhouse
# 9           26                  DreamWorks Shrek's Swamp Stories
# 10          28                                          Girlboss
# 11          37                                             Reign
# 12          38                               The Vampire Diaries
# ...

# %% [markdown]
# ### When was each movie released to netflix and how does it compare to its overall genre rating?

# %%
df1 = df.loc[df['date_added']==2017]
df2 = df.loc[df['date_added']==2019]
df3 = df.loc[df['date_added']==2016]
df4 = df.loc[df['date_added']==2018]
df5 = df.loc[df['date_added']==2015]
df6 = df.loc[df['date_added']==2014]
df7 = df.loc[df['date_added']==2013]
df8 = df.loc[df['date_added']==2012]
# Out:
# array(['TV-14', 'TV-PG', 'TV-MA', 'TV-Y7', 'TV-G', 'TV-Y', 'TV-Y7-FV'],
#       dtype=object)

# %%
g = sns.FacetGrid(df, col="date_added")
g.map(plt.hist, "mpaa rating");
