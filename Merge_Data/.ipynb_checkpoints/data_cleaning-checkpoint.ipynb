# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
netflixDf = pd.read_csv('netflix_titles.csv')
showsDf = pd.read_csv('netflix_shows.csv', encoding='latin-1')

# %% [markdown]
# Calculate the amount of null values in each row

# %%
netflixDf.isnull().sum()/netflixDf.shape[0]*100
# Out:
# show_id          0.000000
# type             0.000000
# title            0.000000
# director        31.584857
# cast             9.143407
# country          7.635547
# date_added       0.176452
# release_year     0.000000
# rating           0.160411
# duration         0.000000
# listed_in        0.000000
# description      0.000000
# dtype: float64

# %%
showsDf.isnull().sum()/showsDf.shape[0]*100
# Out:
# title                 0.0
# rating                0.0
# ratingLevel           5.9
# ratingDescription     0.0
# release year          0.0
# user rating score    39.5
# user rating size      0.0
# dtype: float64

# %% [markdown]
# Merge the two data frames, apply some data cleaning.

# %%
pd.set_option('display.max_rows', None)

tempDf=pd.DataFrame(columns=['title', 'rating'])
tempDf['title'] = showsDf['title']
tempDf['rating'] = showsDf['user rating score']

# Drop entries that don't have a user score
tempDf = tempDf.dropna()

# In this data set, multiple seasons of a show are input with the same title.
# To circumvent duplicate data, we grouped the common titles together and
# took the average of the ratings. Instead of ratings for each season, we now
# have the average rating of the show.
tempDf = tempDf.groupby(['title']).mean()

# Inner join from new dataframe with the netflix dataframe
merged_inner = pd.merge(left=netflixDf, right=tempDf, left_on='title', right_on='title')

# Some movies and TV Shows have the same name, so we drop all the movies
# As the ratings data frame only has ratings for TV Shows
merged_inner = merged_inner.loc[merged_inner['type'] == 'TV Show']

# Remove all entries that were released after 2018, since the ratings only
# deals with TV Shows released 2017 and before.
merged_inner = merged_inner.loc[merged_inner['release_year'] < 2018]

# %% [markdown]
# Final cleaning of the data, dropped rows we won't use in analysis and renamed ambiguous columns

# %%
finalDf = merged_inner
finalDf = finalDf.drop(['show_id', 'type', 'director', 'cast'], axis=1)
finalDf = finalDf.rename(columns={"rating_x": "mpaa rating", "rating_y": "user_rating"})

finalDf
# Out:
#                                                 title  \
# 4                                           Limitless
# 5                   Gilmore Girls: A Year in the Life
# 8                                             Charmed
# 10                                            Revenge
# 11                                    The Jungle Book
# 13   American Crime Story: The People v. O.J. Simpson
# 14                                     Dave Chappelle
# 17                                        Cheer Squad
# 21                      Barbie Life in the Dreamhouse
# 26                   DreamWorks Shrek's Swamp Stories
# 28                                           Girlboss
# 37                                              Reign
# 38                                The Vampire Diaries
# 42                                 Person of Interest
# 48                                             Naruto
# 50                                             Narcos
# 51                                     Forensic Files
# 52                                    Sofia the First
# 53                                        Gossip Girl
# 54                                        The Fosters
# 55                                      Goldie & Bear
# 57                                    Haters Back Off
# 59                                      Gilmore Girls
# 60                                          Skin Wars
# 62                                         Goosebumps
# 63                               The Magic School Bus
# 65                                           Longmire
# 66                                     That '70s Show
# 68                                             Bitten
# 73                                           Sherlock
# 74                             Hunter X Hunter (2011)
# 78                                   Better Call Saul
# 79                                            Mad Men
# 80                                    The Night Shift
# 83                                     Criminal Minds
# 89                                 Dawn of the Croods
# 92                                               Glee
# 93                                               NCIS
# 96                               Parks and Recreation
# 97                                             Pocoyo
# 98                                             Dexter
# 99                       Mighty Morphin Power Rangers
# 100                                 The Office (U.S.)
# 101                               H2O: Just Add Water
# 102                                       Bates Motel
# 109                                      Nurse Jackie
# 110                                     The West Wing
# 112                                  Private Practice
# 114                                     Hart of Dixie
# 116                              All Hail King Julien
# 121                                      Breaking Bad
# 123                                         Heartland
# 124                                      The Get Down
# 125                                       Chewing Gum
# 5    Set nearly a decade after the finale of the or...    77.000000
# 8    After a trio of sisters discover an ancient te...    90.000000
# 10   After a mother and her daughter are gang-raped...    84.000000
# 11   This animated series follows young Mowgli and ...    97.000000
# 13   This anthology series dramatizes historic crim...    79.000000
# 14   Comedy icon Dave Chappelle makes his triumphan...    94.000000
# 17   Follow the Great White Sharks, a world-champio...    61.000000
# 21   Join blond icon Barbie and her fabulous friend...    85.000000
# 26   Shrek celebrates Halloween, Puss in Boots is c...    56.000000
# 28   Rebellious and broke, Sophia stumbles into cre...    94.000000
# 37   This vivid historical drama series tells of th...    79.000000
# 38   Trapped in adolescent bodies, feuding vampire ...    91.000000
# 42   Ex-CIA agent John Reese and enigmatic billiona...    93.000000
# 48   Guided by the spirit demon within him, orphane...    88.000000
# 50   The true story of Colombia's infamously violen...    94.000000
# 51   Detectives and crime lab technicians use the l...    88.000000
# 52   When her commoner mother marries the king, ave...    82.000000
# 53   A group of hyperprivileged Manhattan private-s...    96.000000
# 54   This offbeat drama charts the ups and downs of...    73.000000
# 55   Best pals Goldie and Bear, from "Goldilocks an...    77.000000
# 57   Determined to make it big, the confident but c...    58.000000
# 59   Fiercely independent single mom Lorelai raises...    91.000000
# 60   Artists test their creativity and body paintin...    69.000000
# 62   R.L. Stine's tales take on a life of their own...    88.666667
# 63   Join Ms. Frizzle as the Magic School Bus trave...    81.000000
# 65   This contemporary crime thriller focuses on a ...    92.000000
# 66   Feel groovy in 1970s suburbia, where a teen an...    89.000000
# 68   Elena Michaels tries to stray from the pack of...    56.000000
# 73   In this updated take on Sir Arthur Conan Doyle...    95.000000
# 74   To fulfill his dreams of becoming a legendary ...    57.000000
# 78   This Emmy-nominated prequel to "Breaking Bad" ...    95.000000
# 79   Set in 1960s New York City, this award-winning...    75.000000
# 80   After returning from a dangerous tour of duty,...    93.000000
# 83   This intense police procedural follows a group...    98.000000
# 89   The world's first family is back for more laug...    72.000000
# 92   Amid relationship woes and personal attacks fr...    92.000000
# 93   Follow the quirky agents of the NCIS – the Nav...    97.000000
# 96   In this Emmy-nominated comedy, an employee wit...    94.000000
# 97   Discovery is the name of the game for friendly...    67.000000
# 98   By day, mild-mannered Dexter is a blood-spatte...    95.000000
# 99   Five average teens are chosen by an intergalac...    73.000000
# 100  This hit comedy chronicles the foibles of disg...    97.000000
# 101  The gals in this fantasy series cope with the ...    74.000000
# 102  When his father dies, Norman Bates and his mot...    83.000000
# 109  A flawed but dedicated ER nurse works in a New...    82.000000
# 110  This powerful political epic chronicles the tr...    79.000000
# 112  At Oceanside Wellness Center, Dr. Addison Mont...    88.000000
# 114  Fast-talking city girl Zoe Hart winds up patch...    81.000000
# 116  In this Emmy winner for Outstanding Children's...    71.000000
# 121  A high school chemistry teacher dying of cance...    97.000000
# 123  Spunky teenager Amy is reeling from the sudden...    85.000000
# 124  In 1977 New York City, the talented and soulfu...    80.000000
# 125  The virginal Tracey, who was raised in a stric...    93.000000
# 126  Still rebounding from a breakup, Jessica Day m...    91.000000
# 127  Full of funny one-liners and always ready for ...    61.000000
# 128  A suburban mother starts selling marijuana to ...    85.000000
# 129  This hit sitcom follows the merry misadventure...    98.000000

# %%
finalDf.isnull().sum()/finalDf.shape[0]*100
# Out:
# title           0.000000
# country         1.724138
# date_added      1.724138
# release_year    0.000000
# mpaa rating     0.000000
# duration        0.000000
# listed_in       0.000000
# description     0.000000
# user_rating     0.000000
# dtype: float64
